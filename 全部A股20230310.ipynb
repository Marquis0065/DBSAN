# %%
import os
os.__file__
# Out:
# 'C:\\ProgramData\\Anaconda3\\envs\\pythonProject1\\lib\\os.py'

# %%
pd.concat([data,pd.DataFrame(fa_scores)],axis=1).corr()
# Out:
#           涨幅%        现价        涨跌        买价        卖价        总量        现量  \
# 涨幅%  1.000000  0.056011  0.544301  0.055965  0.055999  0.009140 -0.028981
# 现价   0.056011  1.000000 -0.411304  0.999999  1.000000 -0.114379 -0.108236
# 涨跌   0.544301 -0.411304  1.000000 -0.411321 -0.411300  0.049485  0.032182
# 买价   0.055965  0.999999 -0.411321  1.000000  0.999999 -0.114352 -0.108213
# 卖价   0.055999  1.000000 -0.411300  0.999999  1.000000 -0.114405 -0.108258
# 总量   0.009140 -0.114379  0.049485 -0.114352 -0.114405  1.000000  0.907943
# 现量  -0.028981 -0.108236  0.032182 -0.108213 -0.108258  0.907943  1.000000
# 涨速%  0.172521 -0.001009  0.125954 -0.001205 -0.001081 -0.038001 -0.037198
# 换手%  0.152315  0.053656  0.005371  0.053701  0.053645  0.164548  0.150140
# 今开   0.044653  0.999806 -0.427787  0.999805  0.999806 -0.114768 -0.108333
# 最高   0.052661  0.999898 -0.417489  0.999897  0.999898 -0.113789 -0.107660
# 最低   0.049492  0.999875 -0.420992  0.999876  0.999874 -0.114482 -0.108128
# ...

# %%
# 1.因子分析的概念很多，作为刚入门的人，我们可以认为因子分析是主成分分析的延续
from fa_kit import FactorAnalysis
from fa_kit import plotting as fa_plotting

fa = FactorAnalysis.load_data_samples(
        std_data,     #标准化数据
        preproc_demean=True,
        preproc_scale=True
        )
fa.extract_components()
# 2.设定提取主成分的方式，建议使用“top_n”法
fa.find_comps_to_retain(method='top_n', num_keep = 5)
# 3.通过最大方差法进行因子旋转
fa.rotate_components()
#查看因子权重（旋转后）
# fa.comps['rot']
pd.DataFrame(fa.comps['rot'])
#因子得分
fa_scores = fa.get_component_scores(std_data)
fa_scores
# Out:
# array([0, 1, 2, 3, 4], dtype=int64)
#            0         1         2         3         4
# 0   0.081352 -0.015133  0.731900  0.090850  0.019483
# 1   0.372539 -0.005908  0.010261 -0.010655 -0.000985
# 2  -0.100249  0.023648  0.673583 -0.108496 -0.031754
# 3   0.372539 -0.005884  0.010253 -0.010633 -0.001181
# 4   0.372539 -0.005933  0.010269 -0.010664 -0.001060
# 5  -0.027430  0.626099  0.017243 -0.006334  0.004945
# 6  -0.026791  0.621923 -0.003620 -0.053100  0.007431
# 7  -0.000307  0.001903 -0.002076 -0.002092  0.994910
# 8  -0.001401  0.018958 -0.060943  0.705238 -0.065533
# 9   0.371428 -0.006503 -0.003171 -0.008811 -0.000067
# 10  0.371999 -0.006125  0.004951 -0.005373 -0.002169
# 11  0.371996 -0.005986  0.002968 -0.012070 -0.000622
# 12  0.371247 -0.006392 -0.005241 -0.008072 -0.000250
# 13  0.113455  0.467666 -0.020433  0.106313 -0.011137
# 14 -0.009177 -0.032981  0.075989  0.683951  0.065263
# array([[-0.42091143,  3.95623174,  0.45448591, -0.49879789, -0.06863735],
# ...

# %%
pd.concat([data,score],axis=1).corr()
# Out:
#             涨幅%        现价        涨跌        买价        卖价        总量        现量  \
# 涨幅%    1.000000  0.056066  0.546411  0.056014  0.056051 -0.018193 -0.045171
# 现价     0.056066  1.000000 -0.429223  0.999999  1.000000 -0.108208 -0.099648
# 涨跌     0.546411 -0.429223  1.000000 -0.429241 -0.429221  0.042166  0.026689
# 买价     0.056014  0.999999 -0.429241  1.000000  0.999999 -0.108177 -0.099622
# 卖价     0.056051  1.000000 -0.429221  0.999999  1.000000 -0.108232 -0.099668
# 总量    -0.018193 -0.108208  0.042166 -0.108177 -0.108232  1.000000  0.924971
# 现量    -0.045171 -0.099648  0.026689 -0.099622 -0.099668  0.924971  1.000000
# 涨速%    0.165643 -0.005270  0.124608 -0.005478 -0.005341 -0.036489 -0.057716
# 换手%    0.144631  0.053134 -0.008786  0.053182  0.053126  0.133517  0.127881
# 今开     0.044748  0.999812 -0.445237  0.999811  0.999812 -0.108431 -0.099638
# 最高     0.052346  0.999898 -0.435876  0.999897  0.999898 -0.107635 -0.099057
# ...

# %%
share_pca.sort_values(by=[0,1,2,3,4],ascending=False)
# Out:
#           代码    名称   涨幅%       现价     涨跌       买价       卖价       总量     现量  \
# 3124  600519  贵州茅台 -1.13  1750.00 -20.02  1750.00  1750.01    21161    658
# 4417  688032  禾迈股份  0.38   782.98   2.99   782.80   782.98     2606     13
# 2348  300896   爱美客 -2.21   537.16 -12.13   537.16   537.47    17213    162
# 4685  688348  昱能科技 -4.15   428.53 -18.55   428.10   428.53    10382   1208
# 4648  688301  奕瑞科技  0.30   423.00   1.27   423.00   423.39     1202     47
# ...      ...   ...   ...      ...    ...      ...      ...      ...    ...
# 2845  600157  永泰能源 -1.27     1.55  -0.02     1.55     1.56  2074372  41209
# 3587  601258  庞大集团  0.88     1.15   0.01     1.14     1.15  2643516  31849
# 35        46  泛海控股  1.67     1.22   0.02     1.22     1.23   723127  57646
# 3589  601288  农业银行 -1.00     2.98  -0.03     2.98     2.99  3417306  62356
# 2733  600010  包钢股份 -2.00     1.96  -0.04     1.96     1.97  2915596  55714
#
# ...

# %%
#合并
share_pca = pd.concat([a_share,score],axis=1)
share_pca
# Out:
#           代码    名称   涨幅%     现价    涨跌     买价     卖价      总量    现量   涨速%  ...  \
# 0          1  平安银行 -0.45  13.14 -0.06  13.14  13.15  856996  8175  0.00  ...
# 1          2  万 科Ａ -1.80  15.83 -0.29  15.83  15.84  532489  6757 -0.05  ...
# 2          4  ST国华  0.20  10.08  0.02  10.07  10.08   16755   117 -0.09  ...
# 3          5  ST星源  0.00   1.82  0.00   1.82   1.83   72514  1056  0.00  ...
# 4          6  深振业Ａ  1.99   5.65  0.11   5.65   5.66  565038  5916 -0.17  ...
# ...      ...   ...   ...    ...   ...    ...    ...     ...   ...   ...  ...
# 5068  873169  七丰精工 -1.29   6.12 -0.08   6.11   6.12    4990   202  0.49  ...
# 5069  873223  荣亿精密 -0.30   3.35 -0.01   3.35   3.36    5786   100  0.00  ...
# 5070  873305  九菱科技  0.68  10.39  0.07  10.38  10.39     499    10  0.68  ...
# 5071  873339  恒太照明 -0.19   5.12 -0.01   5.10   5.12    1984     1  0.59  ...
# 5072  873527   夜光明  0.12   8.10  0.01   8.08   8.09     327     9  0.00  ...
#
# ...

# %%
#主成分得分
score= pd.DataFrame(pca.fit_transform(std_data))
score
# Out:
#              0         1         2         3         4
# 0    -0.573557  3.534579 -0.857064 -1.581952 -0.479226
# 1    -0.395169  2.216934 -1.203142 -0.995345 -0.347510
# 2    -0.888041 -0.498746  0.781045  0.216343 -0.550398
# 3    -1.400010 -0.397536  0.512439 -0.202264 -0.298680
# 4    -1.197456  2.145977  1.022726 -0.036543 -1.008596
# ...        ...       ...       ...       ...       ...
# 5068 -1.112852  0.033992  2.057340  1.057499  2.160285
# 5069 -1.287352 -0.525155  0.772702  0.293883 -0.106297
# 5070 -0.896145 -0.869916  1.351356 -1.589354  1.589916
# 5071 -1.196128 -0.649930  1.374168 -0.750931  1.708591
# 5072 -1.017667 -0.954495  0.225803 -0.711455 -0.547609
#
# [5073 rows x 5 columns]

# %%
pca = PCA(n_components=5)
pca.fit(std_data)
# 单个主成分解释的方差(特征值)
pca.explained_variance_
# 单个主成分解释的方差比率
pca.explained_variance_ratio_
# Out:
# PCA(n_components=5)
# array([7.30550413, 2.46701771, 1.72976892, 1.13079792, 0.89897533])
# array([0.4869376 , 0.16443543, 0.1152952 , 0.07537167, 0.05991988])

# %%
# 单个主成分解释的方差(特征值)
pca.explained_variance_
# 单个主成分解释的方差比率
pca.explained_variance_ratio_
# Out:
# array([7.32235104e+00, 2.45504015e+00, 1.72437689e+00, 1.17085769e+00,
#        1.00000462e+00, 9.10878931e-01, 5.95022356e-01, 4.55885088e-01,
#        2.98560634e-01, 7.05651764e-02, 1.66615576e-04, 6.16357813e-05,
#        3.84200578e-05, 9.06960445e-07, 2.78664895e-07, 7.04432188e-31])
# array([4.57537976e-01, 1.53403476e-01, 1.07747895e-01, 7.31611822e-02,
#        6.24854078e-02, 5.69163785e-02, 3.71800428e-02, 2.84860340e-02,
#        1.86555968e-02, 4.40927345e-03, 1.04109941e-05, 3.85131913e-06,
#        2.40068189e-06, 5.66715314e-08, 1.74124091e-08, 4.40165291e-32])

# %%
# 4.使用sklearn的主成分分析，用于判断保留主成分的数量
from sklearn.decomposition import PCA
# 建立模型
# n_components:保留主成分的个数，初始设置一般为变量的个数
pca = PCA(n_components=16)
pca.fit(data)
# Out:
# PCA(n_components=16)

# %%
# 3.做主成分之前，进行中心标准化
from sklearn import preprocessing
data =preprocessing.scale(data)
data
# Out:
# array([[ 0.48994807, -0.27793132,  0.24643756, ..., -0.15160804,
#          2.68804185, -0.54565257],
#        [-0.23573786, -0.2203387 ,  0.03017589, ..., -0.14783576,
#          1.90030979, -0.62056418],
#        [ 0.73184339, -0.52029137,  0.30285364, ...,  0.04030497,
#         -0.4211984 ,  0.15851653],
#        ...,
#        [ 1.09737408, -0.33680854,  0.36867241, ..., -0.12939195,
#         -0.45650694, -0.33590008],
#        [ 0.62970981, -0.44963871,  0.29345096, ..., -0.14833687,
#         -0.45512651,  0.81773866],
#        [ 0.7963488 , -0.38583721,  0.31225632, ..., -0.13962305,
#         -0.45721193, -0.83031668]])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5073 entries, 0 to 5072
# Data columns (total 15 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   涨幅%     5073 non-null   float64
#  1   现价      5073 non-null   float64
#  2   涨跌      5073 non-null   float64
#  3   买价      5073 non-null   float64
#  4   卖价      5073 non-null   float64
#  5   总量      5073 non-null   int64
#  6   现量      5073 non-null   int64
#  7   涨速%     5073 non-null   float64
#  8   换手%     5073 non-null   float64
#  9   今开      5073 non-null   float64
#  10  最高      5073 non-null   float64
#  11  最低      5073 non-null   float64
#  12  昨收      5073 non-null   float64
#  13  总金额     5073 non-null   float64
#  14  量比      5073 non-null   float64
# dtypes: float64(13), int64(2)
# memory usage: 594.6 KB

# %%
for i in data.columns:
    data[i]=pd.to_numeric(data[i],errors='coerce')
data.isnull().sum()
# Out:
# 涨幅%    0
# 现价     0
# 涨跌     0
# 买价     0
# 卖价     0
# 总量     0
# 现量     0
# 涨速%    0
# 换手%    0
# 今开     0
# 最高     0
# 最低     0
# 昨收     0
# 总金额    0
# 量比     0
# dtype: int64

# %%
data = data.astype(float,errors='ignore')

# %%
data=data.apply(pd.to_numeric,errors='ignore')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5121 entries, 0 to 5130
# Data columns (total 16 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   涨幅%     5121 non-null   object
#  1   现价      5121 non-null   float64
#  2   涨跌      5121 non-null   object
#  3   买价      5121 non-null   object
#  4   卖价      5121 non-null   object
#  5   总量      5121 non-null   float64
#  6   现量      5121 non-null   float64
#  7   涨速%     5121 non-null   object
#  8   换手%     5121 non-null   object
#  9   今开      5121 non-null   object
#  10  最高      5121 non-null   object
#  11  最低      5121 non-null   object
#  12  昨收      5121 non-null   object
#  13  市盈(动)   5121 non-null   object
#  14  总金额     5121 non-null   float64
#  15  量比      5121 non-null   object
# dtypes: float64(4), object(12)
# memory usage: 680.1+ KB

# %%
data= a_share.iloc[:,2:-1]
data.head()
# Out:
#     涨幅%     现价    涨跌     买价     卖价      总量    现量   涨速%   换手%     今开     最高  \
# 0 -0.45  13.14 -0.06  13.14  13.15  856996  8175  0.00  0.44  13.00  13.27
# 1 -1.80  15.83 -0.29  15.83  15.84  532489  6757 -0.05  0.55  15.99  16.05
# 2  0.20  10.08  0.02  10.07  10.08   16755   117 -0.09  1.41  10.02  10.30
# 3  0.00   1.82  0.00   1.82   1.83   72514  1056  0.00  0.69   1.81   1.83
# 4  1.99   5.65  0.11   5.65   5.66  565038  5916 -0.17  4.19   5.48   5.78
#
#       最低     昨收        总金额    量比
# 0  13.00  13.20  112855.83  0.68
# 1  15.77  16.12   84597.59  0.63
# 2   9.95  10.06    1699.45  1.37
# 3   1.80   1.82    1318.34  1.15
# 4   5.36   5.54   31484.58  1.53

# %%
a_share.shape
a_share.dropna(inplace=True)
a_share.shape
# Out:
# (5132, 19)
# (5121, 19)

# %%
from sklearn import datasets
iris = datasets.load_iris()
#打印数据集的内容
iris.data
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
# ...

# %%
missingno.bar(a_share)
# Out:
# <AxesSubplot: >

# %%
#查看缺失值
import missingno
missingno.matrix(a_share);

# %%
a_share.isnull().mean()
# Out:
# 代码      0.0
# 名称      0.0
# 涨幅%     0.0
# 现价      0.0
# 涨跌      0.0
# 买价      0.0
# 卖价      0.0
# 总量      0.0
# 现量      0.0
# 涨速%     0.0
# 换手%     0.0
# 今开      0.0
# 最高      0.0
# 最低      0.0
# 昨收      0.0
# 总金额     0.0
# 量比      0.0
# 细分行业    0.0
# dtype: float64

# %%
a_share.shape
a_share.dropna(inplace=True)
a_share.shape
# Out:
# (5073, 18)
# (5073, 18)

# %%
import pandas as pd
import os

os.chdir(r'C:\Users\fzh00\Desktop\文件\excel')
os.getcwd()
a_share = pd.read_excel('全部A股.xlsx')
a_share.shape
# Out:
# 'C:\\Users\\fzh00\\Desktop\\文件\\excel'
# (5073, 18)

# %%
import seaborn
import matplotlib.pyplot as plt
plt.style.use('seaborn')
#设置字体为黑色
plt.rcParams['font.family']='SimHei'
#显示符号
plt.rcParams['axes.unicode_minus']=False#显示负号\n",
# %matplotlib inline
# Out:
# C:\Users\fzh00\AppData\Local\Temp\ipykernel_1904\3254088630.py:3: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn')

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
